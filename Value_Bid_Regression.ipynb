# %%
import pandas as pd

# %%
value_bid = pd.read_csv('value_bid.csv')
value_bid
# Out:
#              player  bid_price(dollar,mil)  value_points19
# 0          MS Dhoni               2.100000          118.20
# 1         HH Pandya               1.500000          112.16
# 2         RA Jadeja               0.981400          102.83
# 3        AD Russell               0.981400           99.16
# 4           RR Pant               1.100000           90.03
# 5           S Gopal               0.028040           85.75
# 6       JM Bairstow               0.308440           85.62
# 7         Q de Kock               0.392560           85.26
# 8       Imran Tahir               0.140200           82.50
# 9          K Rabada               0.588840           82.16
# 10        DA Warner               1.700000           81.70
# 11         KL Rahul               0.500000           78.90
# 12        JC Archer               1.000000           76.00
# 13     F du Plessis               0.224320           73.50
# 14         AR Patel               0.714285           73.33
# ...

# %%
import numpy as np
from matplotlib import pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
value_bidplot = sns.lmplot("value_points19", "bid_price(dollar,mil)", value_bid)

# %%
value_bid2 = value_bid.sort_values('bid_price(dollar,mil)', ascending=False)
value_bid2
# Out:
#              player  bid_price(dollar,mil)  value_points19
# 41          V Kohli               2.400000           53.14
# 0          MS Dhoni               2.100000          118.20
# 10        DA Warner               1.700000           81.70
# 35        SPD Smith               1.700000           54.87
# 18   AB de Villiers               1.500000           66.70
# 1         HH Pandya               1.500000          112.16
# 15        MK Pandey               1.400000           68.00
# 17      Rashid Khan               1.300000           66.80
# 19        KH Pandya               1.200000           66.63
# 46        SV Samson               1.100000           51.70
# 4           RR Pant               1.100000           90.03
# 22         R Ashwin               1.100000           63.40
# 28        SM Curran               1.020000           58.75
# 12        JC Archer               1.000000           76.00
# 31       KD Karthik               1.000000           56.62
# ...
