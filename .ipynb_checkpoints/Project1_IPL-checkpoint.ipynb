# %%
import pandas as pd
import numpy as np

# %%
batting19 = pd.read_csv('batting_2019.csv')
bowling19 = pd.read_csv('bowling_2019.csv')
ipl2019 = pd.merge(batting19, bowling19, on='player')
ipl2019
# Out:
#        ave   bf fiftys fours_x    hs hundreds inns_x  mat_x no  \
# 0        -    7      0       0    3*        0      1      5  1
# 1     4.50    9      0       1    5*        0      3      3  1
# 2    12.20   57      0       5    24        0      5      8  0
# 3    25.53  234      2      26    58        0     13     13  0
# 4     0.00    1      0       0     0        0      1      9  0
# 5    27.50  133      2      16    66        0     10     11  2
# 6    33.50   40      0       4   27*        0      5     11  3
# 7        -    -      -       -     -        -      -      3  -
# 8     3.00    5      0       0    1*        0      3     10  2
# 9     8.40   28      0       3   17*        0      6     14  1
# 10       -    3      0       1    4*        0      1      1  1
# 11   55.62  283      2      48   114        1     10     10  2
# 12       -    1      0       0    1*        0      1      3  1
# 13       -    -      -       -     -        -      -      5  -
# ...

# %%
ipl2019=ipl2019[['ave','inns_x','player','sr','bowl_sr','ct','econ','inns_y','wkts']].set_index('player')
ipl2019
# Out:
#                      ave inns_x      sr bowl_sr  ct   econ inns_y wkts
# player
# VR Aaron               -      1   42.85    18.0   1   9.66      5    4
# Abhishek Sharma     4.50      3  100.00    12.0   1  10.50      2    1
# AD Nath            12.20      5  107.01       -   1      -      -    -
# MA Agarwal         25.53     13  141.88       -   7      -      -    -
# KK Ahmed            0.00      1    0.00    11.0   0   8.23      9   19
# MM Ali             27.50     10  165.41    25.0   1   6.76      9    6
# JC Archer          33.50      5  167.50    23.4   3   6.76     11   11
# Arshdeep Singh         -      -       -    20.0   0  10.90      3    3
# M Ashwin            3.00      3   60.00    40.8   3   7.50     10    5
# R Ashwin            8.40      6  150.00    22.0   4   7.27     14   15
# Avesh Khan             -      1  133.33       -   1  10.00      1    0
# JM Bairstow        55.62     10  157.24       -   9      -      -    -
# ...

# %%
ipl_19 = ipl2019.replace('-', np.nan)
ipl_19
# Out:
#                      ave inns_x      sr bowl_sr  ct   econ inns_y wkts
# player
# VR Aaron             NaN      1   42.85    18.0   1   9.66      5    4
# Abhishek Sharma     4.50      3  100.00    12.0   1  10.50      2    1
# AD Nath            12.20      5  107.01     NaN   1    NaN    NaN  NaN
# MA Agarwal         25.53     13  141.88     NaN   7    NaN    NaN  NaN
# KK Ahmed            0.00      1    0.00    11.0   0   8.23      9   19
# MM Ali             27.50     10  165.41    25.0   1   6.76      9    6
# JC Archer          33.50      5  167.50    23.4   3   6.76     11   11
# Arshdeep Singh       NaN    NaN     NaN    20.0   0  10.90      3    3
# M Ashwin            3.00      3   60.00    40.8   3   7.50     10    5
# R Ashwin            8.40      6  150.00    22.0   4   7.27     14   15
# Avesh Khan           NaN      1  133.33     NaN   1  10.00      1    0
# JM Bairstow        55.62     10  157.24     NaN   9    NaN    NaN  NaN
# ...

# %%
ipl_19['ave'] = pd.to_numeric(ipl_19['ave'])
ipl_19['inns_x'] = pd.to_numeric(ipl_19['inns_x'])
ipl_19['sr'] = pd.to_numeric(ipl_19['sr'])
ipl_19['bowl_sr'] = pd.to_numeric(ipl_19['bowl_sr'])
ipl_19['ct'] = pd.to_numeric(ipl_19['ct'])
ipl_19['econ'] = pd.to_numeric(ipl_19['econ'])
ipl_19['inns_y'] = pd.to_numeric(ipl_19['inns_y'])
ipl_19['wkts'] = pd.to_numeric(ipl_19['wkts'])

# %%
print(ipl_19['ave'].dtype)
# Out:
# float64

# %%
ipl_19 = ipl_19.replace(np.nan,0)
ipl_19
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts
# player
# VR Aaron            0.00     1.0   42.85     18.0   1   9.66     5.0   4.0
# Abhishek Sharma     4.50     3.0  100.00     12.0   1  10.50     2.0   1.0
# AD Nath            12.20     5.0  107.01      0.0   1   0.00     0.0   0.0
# MA Agarwal         25.53    13.0  141.88      0.0   7   0.00     0.0   0.0
# KK Ahmed            0.00     1.0    0.00     11.0   0   8.23     9.0  19.0
# MM Ali             27.50    10.0  165.41     25.0   1   6.76     9.0   6.0
# JC Archer          33.50     5.0  167.50     23.4   3   6.76    11.0  11.0
# Arshdeep Singh      0.00     0.0    0.00     20.0   0  10.90     3.0   3.0
# M Ashwin            3.00     3.0   60.00     40.8   3   7.50    10.0   5.0
# R Ashwin            8.40     6.0  150.00     22.0   4   7.27    14.0  15.0
# Avesh Khan          0.00     1.0  133.33      0.0   1  10.00     1.0   0.0
# ...

# %%
ipl_19['catch_val'] = ipl_19['ct']*2.5
ipl_19
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts  \
# player
# VR Aaron            0.00     1.0   42.85     18.0   1   9.66     5.0   4.0
# Abhishek Sharma     4.50     3.0  100.00     12.0   1  10.50     2.0   1.0
# AD Nath            12.20     5.0  107.01      0.0   1   0.00     0.0   0.0
# MA Agarwal         25.53    13.0  141.88      0.0   7   0.00     0.0   0.0
# KK Ahmed            0.00     1.0    0.00     11.0   0   8.23     9.0  19.0
# MM Ali             27.50    10.0  165.41     25.0   1   6.76     9.0   6.0
# JC Archer          33.50     5.0  167.50     23.4   3   6.76    11.0  11.0
# Arshdeep Singh      0.00     0.0    0.00     20.0   0  10.90     3.0   3.0
# M Ashwin            3.00     3.0   60.00     40.8   3   7.50    10.0   5.0
# R Ashwin            8.40     6.0  150.00     22.0   4   7.27    14.0  15.0
# Avesh Khan          0.00     1.0  133.33      0.0   1  10.00     1.0   0.0
# ...

# %%
def econ_med(x):
    if x['econ'] <= ipl_19['econ'].median():
        return 2.5
    else:
        return 0
    
ipl_19['econ_val'] = ipl_19.apply(econ_med, axis=1)

ipl_19
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts  \
# player
# VR Aaron            0.00     1.0   42.85     18.0   1   9.66     5.0   4.0
# Abhishek Sharma     4.50     3.0  100.00     12.0   1  10.50     2.0   1.0
# AD Nath            12.20     5.0  107.01      0.0   1   0.00     0.0   0.0
# MA Agarwal         25.53    13.0  141.88      0.0   7   0.00     0.0   0.0
# KK Ahmed            0.00     1.0    0.00     11.0   0   8.23     9.0  19.0
# MM Ali             27.50    10.0  165.41     25.0   1   6.76     9.0   6.0
# JC Archer          33.50     5.0  167.50     23.4   3   6.76    11.0  11.0
# Arshdeep Singh      0.00     0.0    0.00     20.0   0  10.90     3.0   3.0
# M Ashwin            3.00     3.0   60.00     40.8   3   7.50    10.0   5.0
# R Ashwin            8.40     6.0  150.00     22.0   4   7.27    14.0  15.0
# Avesh Khan          0.00     1.0  133.33      0.0   1  10.00     1.0   0.0
# ...

# %%
def sr_med(x):
    if x['sr'] >= ipl_19['sr'].median():
        return 2.5
    else:
        return 0
    
ipl_19['bat_sr_val'] = ipl_19.apply(sr_med, axis=1)

ipl_19
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts  \
# player
# VR Aaron            0.00     1.0   42.85     18.0   1   9.66     5.0   4.0
# Abhishek Sharma     4.50     3.0  100.00     12.0   1  10.50     2.0   1.0
# AD Nath            12.20     5.0  107.01      0.0   1   0.00     0.0   0.0
# MA Agarwal         25.53    13.0  141.88      0.0   7   0.00     0.0   0.0
# KK Ahmed            0.00     1.0    0.00     11.0   0   8.23     9.0  19.0
# MM Ali             27.50    10.0  165.41     25.0   1   6.76     9.0   6.0
# JC Archer          33.50     5.0  167.50     23.4   3   6.76    11.0  11.0
# Arshdeep Singh      0.00     0.0    0.00     20.0   0  10.90     3.0   3.0
# M Ashwin            3.00     3.0   60.00     40.8   3   7.50    10.0   5.0
# R Ashwin            8.40     6.0  150.00     22.0   4   7.27    14.0  15.0
# Avesh Khan          0.00     1.0  133.33      0.0   1  10.00     1.0   0.0
# ...

# %%
ipl_19['wkts_val'] = ipl_19['wkts']*2.5
ipl_19
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts  \
# player
# VR Aaron            0.00     1.0   42.85     18.0   1   9.66     5.0   4.0
# Abhishek Sharma     4.50     3.0  100.00     12.0   1  10.50     2.0   1.0
# AD Nath            12.20     5.0  107.01      0.0   1   0.00     0.0   0.0
# MA Agarwal         25.53    13.0  141.88      0.0   7   0.00     0.0   0.0
# KK Ahmed            0.00     1.0    0.00     11.0   0   8.23     9.0  19.0
# MM Ali             27.50    10.0  165.41     25.0   1   6.76     9.0   6.0
# JC Archer          33.50     5.0  167.50     23.4   3   6.76    11.0  11.0
# Arshdeep Singh      0.00     0.0    0.00     20.0   0  10.90     3.0   3.0
# M Ashwin            3.00     3.0   60.00     40.8   3   7.50    10.0   5.0
# R Ashwin            8.40     6.0  150.00     22.0   4   7.27    14.0  15.0
# Avesh Khan          0.00     1.0  133.33      0.0   1  10.00     1.0   0.0
# ...

# %%
def bowl_sr_med(x):
    if x['bowl_sr'] <= ipl_19['bowl_sr'].median():
        return 2.5
    else:
        return 0
    
ipl_19['bowl_sr_val'] = ipl_19.apply(sr_med, axis=1)

ipl_19
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts  \
# player
# VR Aaron            0.00     1.0   42.85     18.0   1   9.66     5.0   4.0
# Abhishek Sharma     4.50     3.0  100.00     12.0   1  10.50     2.0   1.0
# AD Nath            12.20     5.0  107.01      0.0   1   0.00     0.0   0.0
# MA Agarwal         25.53    13.0  141.88      0.0   7   0.00     0.0   0.0
# KK Ahmed            0.00     1.0    0.00     11.0   0   8.23     9.0  19.0
# MM Ali             27.50    10.0  165.41     25.0   1   6.76     9.0   6.0
# JC Archer          33.50     5.0  167.50     23.4   3   6.76    11.0  11.0
# Arshdeep Singh      0.00     0.0    0.00     20.0   0  10.90     3.0   3.0
# M Ashwin            3.00     3.0   60.00     40.8   3   7.50    10.0   5.0
# R Ashwin            8.40     6.0  150.00     22.0   4   7.27    14.0  15.0
# Avesh Khan          0.00     1.0  133.33      0.0   1  10.00     1.0   0.0
# ...

# %%
ipl_19['value_points'] = ipl_19['ave']+ipl_19['catch_val']+ipl_19['econ_val']+ipl_19['bat_sr_val']+ipl_19['wkts_val']+ipl_19['bowl_sr_val']

# %%
ipl_19
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts  \
# player
# VR Aaron            0.00     1.0   42.85     18.0   1   9.66     5.0   4.0
# Abhishek Sharma     4.50     3.0  100.00     12.0   1  10.50     2.0   1.0
# AD Nath            12.20     5.0  107.01      0.0   1   0.00     0.0   0.0
# MA Agarwal         25.53    13.0  141.88      0.0   7   0.00     0.0   0.0
# KK Ahmed            0.00     1.0    0.00     11.0   0   8.23     9.0  19.0
# MM Ali             27.50    10.0  165.41     25.0   1   6.76     9.0   6.0
# JC Archer          33.50     5.0  167.50     23.4   3   6.76    11.0  11.0
# Arshdeep Singh      0.00     0.0    0.00     20.0   0  10.90     3.0   3.0
# M Ashwin            3.00     3.0   60.00     40.8   3   7.50    10.0   5.0
# R Ashwin            8.40     6.0  150.00     22.0   4   7.27    14.0  15.0
# Avesh Khan          0.00     1.0  133.33      0.0   1  10.00     1.0   0.0
# ...

# %%
ipl_19sorted = ipl_19.sort_values('value_points', ascending=False)
pd.set_option('display.max_rows', None)
ipl_19sorted
# Out:
#                      ave  inns_x      sr  bowl_sr  ct   econ  inns_y  wkts  \
# player
# MS Dhoni           83.20    12.0  134.62      0.0  11   0.00     0.0   0.0
# HH Pandya          44.66    15.0  191.42     18.2  11   9.17    16.0  14.0
# RA Jadeja          35.33     9.0  120.45     21.6   9   6.35    16.0  15.0
# AD Russell         56.66    13.0  204.81     16.4   4   9.51    12.0  11.0
# RR Pant            37.53    16.0  162.66      0.0  18   0.00     0.0   0.0
# S Gopal            15.75     7.0  136.95     14.4   5   7.22    14.0  20.0
# JM Bairstow        55.62    10.0  157.24      0.0   9   0.00     0.0   0.0
# Q de Kock          35.26    16.0  132.91      0.0  17   0.00     0.0   0.0
# Imran Tahir         0.00     1.0    0.00     14.8   6   6.69    17.0  26.0
# K Rabada            4.66     4.0   93.33     11.2   6   7.82    12.0  25.0
# DA Warner          69.20    12.0  143.86      0.0   2   0.00     0.0   0.0
# ...

# %%
from matplotlib import pyplot as plt
plt.style.use('ggplot')

# %%
plt.figure(figsize=(16,8))
ipl_19sorted.groupby('player')['value_points'].median().sort_values(ascending=False).plot.bar(color='b')

# %%
plt.figure(figsize=(12,6))
ipl_19sorted.groupby('player')['value_points'].median().sort_values(ascending=False).head(20).plot.bar(color='b')

# %%
import plotly
# connected=True means it will download the latest version of plotly javascript library.
plotly.offline.init_notebook_mode(connected=True)

from plotly.graph_objs import Figure, Histogram, Layout

from plotly.graph_objs import Bar

ipl_19sorted = ipl_19sorted.groupby('player')['value_points'].median().sort_values(ascending=False).head(20).reset_index()

data = [Bar(x=ipl_19sorted['player'], y=ipl_19sorted['value_points'], text=ipl_19sorted['player'])]
layout = Layout(title="IPL 2019: Players with Highest Value Points")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig,show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...

# %%
import pandas as pd
batting18 = pd.read_csv('ipl18bat.csv')
bowling18 = pd.read_csv('ipl18bowl.csv')
ipl2018 = pd.merge(batting18, bowling18, on='player')
ipl2018
# Out:
#     bat_ave bat_inns  bat_mat bat_runs  bat_sr                   player  \
# 0     63.00        3        3       63  190.90          Abhishek Sharma
# 1      9.00        1        1        9   69.23                  AD Nath
# 2     12.00       11       11      120  127.65               MA Agarwal
# 3         -        -        1        -       -                 KK Ahmed
# 4     19.25        4        5       77  167.39                   MM Ali
# 5      5.66        3        3       17   77.27              CJ Anderson
# 6         -        -        1        -       -             Ankit Sharma
# 7         -        1        3        3   75.00            Anureet Singh
# 8      3.00        8       10       15   71.42                JC Archer
# 9      1.00        1        2        1   50.00                 M Ashwin
# 10    12.75        9       14      102  143.66                 R Ashwin
# 11        -        -        2        -       -                  KM Asif
# ...

# %%
ipl2018=ipl2018.set_index('player')
ipl2018 = ipl2018.replace('-', np.nan)

ipl2018['bat_ave'] = pd.to_numeric(ipl2018['bat_ave'])
ipl2018['bat_inns'] = pd.to_numeric(ipl2018['bat_inns'])
ipl2018['bat_mat'] = pd.to_numeric(ipl2018['bat_mat'])
ipl2018['bat_runs'] = pd.to_numeric(ipl2018['bat_runs'])
ipl2018['bat_sr'] = pd.to_numeric(ipl2018['bat_sr'])
ipl2018['bowl_inns'] = pd.to_numeric(ipl2018['bowl_inns'])
ipl2018['bowl_mat'] = pd.to_numeric(ipl2018['bowl_mat'])
ipl2018['bowl_sr'] = pd.to_numeric(ipl2018['bowl_sr'])
ipl2018['catches'] = pd.to_numeric(ipl2018['catches'])
ipl2018['econ'] = pd.to_numeric(ipl2018['econ'])
ipl2018['wkts'] = pd.to_numeric(ipl2018['wkts'])

ipl2018 = ipl2018.replace(np.nan,0)

# %%
ipl2018['catch_val'] = ipl2018['catches']*2.5

def econ_med(x):
    if x['econ'] <= ipl2018['econ'].median():
        return 2.5
    else:
        return 0
    
ipl2018['econ_val'] = ipl2018.apply(econ_med, axis=1)

ipl2018['wkts_val'] = ipl2018['wkts']*2.5

def bat_sr_med(x):
    if x['bat_sr'] >= ipl2018['bat_sr'].median():
        return 2.5
    else:
        return 0
    
ipl2018['bat_sr_val'] = ipl2018.apply(bat_sr_med, axis=1)

def bowl_sr_med(x):
    if x['bowl_sr'] <= ipl2018['bowl_sr'].median():
        return 2.5
    else:
        return 0
    
ipl2018['bowl_sr_val'] = ipl2018.apply(bowl_sr_med, axis=1)

# %%
ipl2018['value_points'] = ipl2018['bat_ave']+ipl2018['catch_val']+ipl2018['econ_val']+ipl2018['bat_sr_val']+ipl2018['wkts_val']+ipl2018['bowl_sr_val']

ipl2018sorted = ipl2018.sort_values('value_points', ascending=False)

ipl2018sorted
# Out:
#                          bat_ave  bat_inns  bat_mat  bat_runs  bat_sr  \
# player
# MS Dhoni                   75.83      15.0       16     455.0  150.66
# HH Pandya                  28.88      13.0       13     260.0  133.33
# DJ Bravo                   35.25      10.0       16     141.0  154.94
# KD Karthik                 49.80      16.0       16     498.0  147.77
# KL Rahul                   54.91      14.0       14     659.0  158.41
# JC Buttler                 54.80      13.0       13     548.0  155.24
# Rashid Khan                11.80       7.0       17      59.0  190.32
# AD Russell                 28.72      14.0       16     316.0  184.79
# KH Pandya                  22.80      13.0       14     228.0  145.22
# HV Patel                   60.00       2.0        5      60.0  181.81
# AJ Tye                      5.33       8.0       14      32.0   84.21
# RA Jadeja                  17.80      10.0       16      89.0  120.27
# ...

# %%
import pandas as pd
import numpy as np
batting17 = pd.read_csv('ipl17bat.csv')
bowling17 = pd.read_csv('ipl17bowl.csv')
ipl2017 = pd.merge(batting17, bowling17, on='player')

ipl2017=ipl2017.set_index('player')
ipl2017 = ipl2017.replace('-', np.nan)

ipl2017['bat_ave'] = pd.to_numeric(ipl2017['bat_ave'])
ipl2017['bat_mat'] = pd.to_numeric(ipl2017['bat_mat'])
ipl2017['bat_runs'] = pd.to_numeric(ipl2017['bat_runs'])
ipl2017['bat_sr'] = pd.to_numeric(ipl2017['bat_sr'])
ipl2017['bowl_mat'] = pd.to_numeric(ipl2017['bowl_mat'])
ipl2017['bowl_sr'] = pd.to_numeric(ipl2017['bowl_sr'])
ipl2017['catches'] = pd.to_numeric(ipl2017['catches'])
ipl2017['econ'] = pd.to_numeric(ipl2017['econ'])
ipl2017['wkts'] = pd.to_numeric(ipl2017['wkts'])

ipl2017 = ipl2017.replace(np.nan,0)
ipl2017
# Out:
#               bat_ave  bat_mat  bat_runs  bat_sr  bowl_mat  bowl_sr  catches  \
# player
# AR Bawne         0.00        1      12.0  100.00         1      0.0        0
# VR Aaron         4.00        6       4.0   40.00         6     17.1        0
# AD Nath          0.00        1       0.0    0.00         1      0.0        0
# MA Agarwal       8.66        3      26.0   96.29         3      0.0        1
# SS Agarwal       0.00        1       0.0    0.00         1     24.0        1
# ...               ...      ...       ...     ...       ...      ...      ...
# J Yadav          0.00        2       0.0    0.00         2      0.0        0
# SA Yadav        17.50       10     105.0  119.31        10      0.0        5
# UT Yadav         0.00       14      10.0   76.92        14     17.1        4
# Yuvraj Singh    28.00       12     252.0  142.37        12     12.0        3
# A Zampa          5.00        6       5.0   71.42         6     17.0        0
#
#                econ  wkts
# player
# ...

# %%
ipl2017['catch_val'] = ipl2017['catches']*2.5

def econ_med(x):
    if x['econ'] <= ipl2017['econ'].median():
        return 2.5
    else:
        return 0
    
ipl2017['econ_val'] = ipl2017.apply(econ_med, axis=1)

ipl2017['wkts_val'] = ipl2017['wkts']*2.5

def bat_sr_med(x):
    if x['bat_sr'] >= ipl2017['bat_sr'].median():
        return 2.5
    else:
        return 0
    
ipl2017['bat_sr_val'] = ipl2017.apply(bat_sr_med, axis=1)

def bowl_sr_med(x):
    if x['bowl_sr'] <= ipl2017['bowl_sr'].median():
        return 2.5
    else:
        return 0
    
ipl2017['bowl_sr_val'] = ipl2017.apply(bowl_sr_med, axis=1)

ipl2017['value_points'] = ipl2017['bat_ave']+ipl2017['catch_val']+ipl2017['econ_val']+ipl2017['bat_sr_val']+\
ipl2017['wkts_val']+ipl2017['bowl_sr_val']

ipl2017sorted = ipl2017.sort_values('value_points', ascending=False)

# %%
pd.set_option('display.max_rows', None)
ipl2017sorted
# Out:
#                    bat_ave  bat_mat  bat_runs  bat_sr  bowl_mat  bowl_sr  \
# player
# DA Warner            58.27       14     641.0  141.81        14      0.0
# AR Patel             28.37       14     227.0  140.12        14     19.2
# JD Unadkat            0.00       12       2.0   40.00        12     11.4
# B Kumar               4.00       14       4.0  100.00        14     12.0
# HH Pandya            35.71       17     250.0  156.25        17     26.0
# A Mishra             49.00       14      49.0   94.23        14     23.3
# BA Stokes            31.60       12     316.0  142.98        12     22.0
# CH Morris            30.80        9     154.0  163.82         9     15.5
# MK Pandey            49.50       14     396.0  128.57        14      0.0
# JJ Bumrah            16.00       16      16.0  133.33        16     17.8
# P Negi               18.00       12     144.0  129.72        12     12.0
# KA Pollard           29.61       17     385.0  139.49        17      0.0
# ...

# %%
batting16 = pd.read_csv('ipl16bat.csv')
bowling16 = pd.read_csv('ipl16bowl.csv')
ipl2016 = pd.merge(batting16, bowling16, on='player')

ipl2016=ipl2016.set_index('player')
ipl2016 = ipl2016.replace('-', np.nan)

ipl2016['bat_ave'] = pd.to_numeric(ipl2016['bat_ave'])
ipl2016['bat_mat'] = pd.to_numeric(ipl2016['bat_mat'])
ipl2016['bat_runs'] = pd.to_numeric(ipl2016['bat_runs'])
ipl2016['bat_sr'] = pd.to_numeric(ipl2016['bat_sr'])
ipl2016['bowl_mat'] = pd.to_numeric(ipl2016['bowl_mat'])
ipl2016['bowl_sr'] = pd.to_numeric(ipl2016['bowl_sr'])
ipl2016['catches'] = pd.to_numeric(ipl2016['catches'])
ipl2016['econ'] = pd.to_numeric(ipl2016['econ'])
ipl2016['wkts'] = pd.to_numeric(ipl2016['wkts'])

ipl2016 = ipl2016.replace(np.nan,0)

# %%
ipl2016['catch_val'] = ipl2016['catches']*2.5

def econ_med(x):
    if x['econ'] <= ipl2016['econ'].median():
        return 2.5
    else:
        return 0
    
ipl2016['econ_val'] = ipl2016.apply(econ_med, axis=1)

ipl2016['wkts_val'] = ipl2016['wkts']*2.5

def bat_sr_med(x):
    if x['bat_sr'] >= ipl2016['bat_sr'].median():
        return 2.5
    else:
        return 0
    
ipl2016['bat_sr_val'] = ipl2016.apply(bat_sr_med, axis=1)

def bowl_sr_med(x):
    if x['bowl_sr'] <= ipl2016['bowl_sr'].median():
        return 2.5
    else:
        return 0
    
ipl2016['bowl_sr_val'] = ipl2016.apply(bowl_sr_med, axis=1)

ipl2016['value_points'] = ipl2016['bat_ave']+ipl2016['catch_val']+ipl2016['econ_val']+ipl2016['bat_sr_val']+\
ipl2016['wkts_val']+ipl2016['bowl_sr_val']

ipl2016sorted = ipl2016.sort_values('value_points', ascending=False)

# %%
ipl2016sorted
# Out:
#                    bat_ave  bat_mat  bat_runs  bat_sr  bowl_mat  bowl_sr  \
# player
# CH Morris            65.00       12     195.0  178.89        12     20.3
# AB de Villiers       52.84       16     687.0  168.79        16      0.0
# V Kohli              81.08       16     973.0  152.03        16      0.0
# YK Pathan            72.20       15     361.0  145.56        15     36.0
# B Kumar               7.16       17      43.0  159.25        17     17.2
# SR Watson            13.76       16     179.0  133.58        16     16.9
# DA Warner            60.57       17     848.0  151.42        17      0.0
# MC Henriques         15.16       17     182.0  115.18        17     26.0
# DJ Bravo             12.37       15      99.0  120.73        15     19.7
# DR Smith             29.45       12     324.0  146.60        12     13.5
# AD Russell           26.85       12     188.0  164.91        12     14.6
# AM Rahane            43.63       14     480.0  126.64        14      0.0
# ...

# %%
import plotly
# connected=True means it will download the latest version of plotly javascript library.
plotly.offline.init_notebook_mode(connected=True)

from plotly.graph_objs import Figure, Histogram, Layout

from plotly.graph_objs import Bar

ipl2017sorted = ipl2017sorted.groupby('player')['value_points'].median().sort_values(ascending=False).head(20).reset_index()

data = [Bar(x=ipl2017sorted['player'], y=ipl2017sorted['value_points'], text=ipl2017sorted['player'])]
layout = Layout(title="IPL 2017: Players with Highest Value Points")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig,show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...

# %%
import plotly
# connected=True means it will download the latest version of plotly javascript library.
plotly.offline.init_notebook_mode(connected=True)

from plotly.graph_objs import Figure, Histogram, Layout

from plotly.graph_objs import Bar

ipl2016sorted = ipl2016sorted.groupby('player')['value_points'].median().sort_values(ascending=False).head(20).reset_index()

data = [Bar(x=ipl2016sorted['player'], y=ipl2016sorted['value_points'], text=ipl2016sorted['player'])]
layout = Layout(title="IPL 2016: Players with Highest Value Points")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig,show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...

# %%
import plotly
# connected=True means it will download the latest version of plotly javascript library.
plotly.offline.init_notebook_mode(connected=True)

from plotly.graph_objs import Figure, Histogram, Layout

from plotly.graph_objs import Bar

ipl2018sorted = ipl2018sorted.groupby('player')['value_points'].median().sort_values(ascending=False).head(20).reset_index()

data = [Bar(x=ipl2018sorted['player'], y=ipl2018sorted['value_points'], text=ipl2018sorted['player'])]
layout = Layout(title="IPL 2018: Players with Highest Value Points")

fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig,show_link=False)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# ...

# %%
ipl_19new = ipl_19.reset_index()
ipl_19new
# Out:
#                 player    ave  inns_x      sr  bowl_sr  ct   econ  inns_y  \
# 0             VR Aaron   0.00     1.0   42.85     18.0   1   9.66     5.0
# 1      Abhishek Sharma   4.50     3.0  100.00     12.0   1  10.50     2.0
# 2              AD Nath  12.20     5.0  107.01      0.0   1   0.00     0.0
# 3           MA Agarwal  25.53    13.0  141.88      0.0   7   0.00     0.0
# 4             KK Ahmed   0.00     1.0    0.00     11.0   0   8.23     9.0
# 5               MM Ali  27.50    10.0  165.41     25.0   1   6.76     9.0
# 6            JC Archer  33.50     5.0  167.50     23.4   3   6.76    11.0
# 7       Arshdeep Singh   0.00     0.0    0.00     20.0   0  10.90     3.0
# 8             M Ashwin   3.00     3.0   60.00     40.8   3   7.50    10.0
# 9             R Ashwin   8.40     6.0  150.00     22.0   4   7.27    14.0
# 10          Avesh Khan   0.00     1.0  133.33      0.0   1  10.00     1.0
# 11         JM Bairstow  55.62    10.0  157.24      0.0   9   0.00     0.0
# ...

# %%
ipl_19new2 = ipl_19new[['player','value_points']]
ipl_19new2
# Out:
#                 player  value_points
# 0             VR Aaron         12.50
# 1      Abhishek Sharma          9.50
# 2              AD Nath         17.20
# 3           MA Agarwal         50.53
# 4             KK Ahmed         47.50
# 5               MM Ali         52.50
# 6            JC Archer         76.00
# 7       Arshdeep Singh          7.50
# 8             M Ashwin         23.00
# 9             R Ashwin         63.40
# 10          Avesh Khan          7.50
# 11         JM Bairstow         85.62
# 12        Basil Thampi          0.00
# 13      JP Behrendorff         12.50
# 14             RK Bhui          9.50
# 15         SW Billings          5.00
# 16           STR Binny         33.33
# 17            TA Boult         29.50
# 18       CR Brathwaite          5.50
# 19            DJ Bravo         61.00
# 20           JJ Bumrah         55.00
# 21          JC Buttler         66.37
# 22         KC Cariappa          5.00
# 23           YS Chahal         55.50
# ...

# %%
ipl_18new = ipl2018.reset_index()
ipl_18new2 = ipl_18new[['player','value_points']]

# %%
ipl_17new = ipl2017.reset_index()
ipl_17new2 = ipl_17new[['player','value_points']]

# %%
ipl_16new = ipl2016.reset_index()
ipl_16new2 = ipl_16new[['player','value_points']]

# %%
ipl_total = pd.merge(ipl_19new2, ipl_18new2, ipl_17new2, ipl_16new2, on='player')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-78-d79bb73e9256> in <module>
# ----> 1 ipl_total = pd.merge(ipl_19new2, ipl_18new2, ipl_17new2, ipl_16new2, on='player')
#
# TypeError: merge() got multiple values for argument 'on'

# %%
Ranks = pd.DataFrame([['MS Dhoni', 'Chennai Super Kings', 2],
                    ['HH Pandya', 'Mumbai Indians', 1],
                    ['RA Jadeja', 'Chennai Super Kings', 2],
                    ['AD Russell', 'Kolkata Knight Riders', 5],
                    ['RR Pant', 'Delhi Capitals', 3],
                    ['S Gopal', 'Rajasthan Royals', 7],
                    ['JM Bairstow', 'Sunrisers Hyderabad', 4],
                    ['Q de Kock', 'Mumbai Indians', 1],
                    ['Imran Tahir', 'Chennai Super Kings', 2],
                    ['K Rabada', 'Delhi Capitals', 3],
                    ['DA Warner', 'Sunrisers Hyderabad', 4],
                    ['KL Rahul', 'Kings XI Punjab', 6],
                    ['JC Archer', 'Rajasthan Royals', 7],
                    ['F du Plessis', 'Chennai Super Kings', 2],
                    ['AR Patel', 'Delhi Capitals', 3],
                    ['MK Pandey', 'Sunrisers Hyderabad', 4],
                    ['MP Stoinis', 'Royal Challengers Bangalore', 8],
                    ['Rashid Khan', 'Sunrisers Hyderabad', 4],
                    ['AB de Villiers', 'Royal Challengers Bangalore', 8],
                    ['KH Pandya', 'Mumbai Indians', 1]],
                   columns = ['Player', 'Team', 'Team_Rank_2019'])
                      
Ranks
# Out:
#             Player                         Team  Team_Rank_2019
# 0         MS Dhoni          Chennai Super Kings               2
# 1        HH Pandya               Mumbai Indians               1
# 2        RA Jadeja          Chennai Super Kings               2
# 3       AD Russell        Kolkata Knight Riders               5
# 4          RR Pant               Delhi Capitals               3
# 5          S Gopal             Rajasthan Royals               7
# 6      JM Bairstow          Sunrisers Hyderabad               4
# 7        Q de Kock               Mumbai Indians               1
# 8      Imran Tahir          Chennai Super Kings               2
# 9         K Rabada               Delhi Capitals               3
# 10       DA Warner          Sunrisers Hyderabad               4
# 11        KL Rahul              Kings XI Punjab               6
# 12       JC Archer             Rajasthan Royals               7
# 13    F du Plessis          Chennai Super Kings               2
# ...

# %%
plt.hist(Ranks['Team_Rank_2019'])
# Out:
# (array([3., 4., 3., 0., 4., 1., 0., 1., 2., 2.]),
#  array([1. , 1.7, 2.4, 3.1, 3.8, 4.5, 5.2, 5.9, 6.6, 7.3, 8. ]),
#  <a list of 10 Patch objects>)

# %%
import seaborn as sns
sns.distplot(Ranks['Team_Rank_2019'])

# %%
sns.kdeplot(Ranks['Team_Rank_2019'], shade=True, label='Estimated PDF of imdb score')
